# %% [markdown]
# <img src="http://imgur.com/1ZcRyrc.png" style="float: left; margin: 15px; height: 80px">
#
# # Project 1
#
# ### Building "Pokemon Stay"
#
# ---
# You are an analyst at a "scrappy" online gaming company that specializes in remakes of last year's fads.
#
# Your boss, who runs the product development team, is convinced that Pokemon Go's fatal flaw was that you had to actually move around outside. She has design mock-ups for a new game called Pokemon Stay: in this version players still need to move, but just from website to website. Pokemon gyms are now popular online destinations, and catching Pokemon in the "wild" simply requires browsing the internet for hours in the comfort of your home.
#
# She wants you to program a prototype version of the game, and analyze the planned content to help the team calibrate the design.

# %% [markdown]
# #### Package imports
#
# The pprint package below is the only package imported here, and it's not even strictly required to do any of the project. Printing python variables and objects with pprint can help to format them in a "prettier" way.

# %%
from pprint import pprint

# %% [markdown]
# <img src="http://imgur.com/l5NasQj.png" style="float: left; margin: 25px 15px 0px 0px; height: 25px">
#
# ## 1. Defining a player
#
# ---
#
# The player variables are:
#
#     player_id : id code unique to each player (integer)
#     player_name : entered name of the player (string)
#     time_played : number of time played the game in minutes (float)
#     player_pokemon: the player's captured pokemon (dictionary)
#     gyms_visited: ids of the gyms that a player has visited (list)
#
# Create the components for a player object by defining each of these variables. The dictionary and list variables should just be defined as empty; you can use any (correctly typed) values for the others.

# %%
playerDict = {
    'player_id': 1,
    'player_name': 'Rob',
    'time_played': 60.00,
    'player_pokemon': {},
    'gyms_visited': []
}

# %% [markdown]
# <img src="http://imgur.com/l5NasQj.png" style="float: left; margin: 25px 15px 0px 0px; height: 25px">
#
# ## 2. Defining "gym" locations
#
# ---
#
# As the sole programmer, Pokemon Stay will have to start small. To begin, there will be 10 different gym location websites on the internet. The gym locations are:
#
#     1. 'reddit.com'
#     2. 'amazon.com'
#     3. 'twitter.com'
#     4. 'linkedin.com'
#     5. 'ebay.com'
#     6. 'netflix.com'
#     7. 'amazon.com'
#     8. 'stackoverflow.com'
#     9. 'github.com'
#     10. 'quora.com'
#
# 1. Set up a list of all the gym locations. This will be a list of strings.
# 2. Append two of these locations to your player's list of visited gyms.
# 3. Print the list.

# %%
gyms = ['reddit.com', 'amazon.com', 'twitter.com', 'linkedin.com', 'ebay.com', 'netflix.com', 'amazon.com', 'stackoverflow.com', 'github.com', 'quora.com']

#Remove duplicate gyms if there are any.    ....there is.
gyms = list(set(gyms))

playerDict['gyms_visited'].append(gyms[0])
playerDict['gyms_visited'].append(gyms[1])

playerDict['gyms_visited']
# Out:
# ['netflix.com', 'stackoverflow.com']

# %% [markdown]
# <img src="http://imgur.com/l5NasQj.png" style="float: left; margin: 25px 15px 0px 0px; height: 25px">
#
# ## 3. Create a pokedex
#
# ---
#
# We also need to create some pokemon to catch. Each pokemon will be defined by these variables:
#
#     pokemon_id : unique identifier for each pokemon (integer)
#     name : the name of the pokemon (string)
#     type : the category of pokemon (string)
#     hp : base hitpoints (integer)
#     attack : base attack (integer)
#     defense : base defense (integer)
#     special_attack : base special attack (integer)
#     special_defense : base sepecial defense (integer)
#     speed : base speed (integer)
#
# We are only going to create 3 different pokemon with these `pokemon_id` and `pokemon_name` values:
#
#     1 : 'charmander'
#     2 : 'squirtle'
#     3 : 'bulbasaur'
#
# Create a dictionary that will contain the pokemon. The keys of the dictionary will be the `pokemon_id` and the values will themselves dictionaries that contain the other pokemon variables. The structure of the pokedex dictionary will start like so:
#
#      {
#          1: {
#                  'name':'charmander',
#                  'type':'fire',
#                  ...
#
# The `type` of charmander, squirtle, and bulbasaur should be `'fire'`, `'water'`, and `'poison'` respectively. The other values are up to you, make them anything you like!
#
# Print (or pretty print) the pokedex dictionary with the 3 pokemon.

# %%
pDex = {
    1: {
        'name': 'Charmander',
        'type': 'fire',
        'hp': 39,
        'attack': 52,
        'defense': 43,
        'special_attack': 60,
        'special_defense': 50,
        'speed': 65
    },
    
    2: {
        'name': 'Squirtle',
        'type': 'water',
        'hp': 44,
        'attack': 48,
        'defense': 65,
        'special_attack': 50,
        'special_defense': 64,
        'speed': 43
    },
    3: {
        'name': 'Bulbasaur',
        'type': 'poison',
        'hp': 45,
        'attack': 49,
        'defense': 49,
        'special_attack': 65,
        'special_defense': 65,
        'speed': 45
    }
    
}

pprint(pDex)
# Out:
# {1: {'attack': 52,
#      'defense': 43,
#      'hp': 39,
#      'name': 'Charmander',
#      'special_attack': 60,
#      'special_defense': 50,
#      'speed': 65,
#      'type': 'fire'},
#  2: {'attack': 48,
#      'defense': 65,
#      'hp': 44,
#      'name': 'Squirtle',
#      'special_attack': 50,
#      'special_defense': 64,
#      'speed': 43,
#      'type': 'water'},
#  3: {'attack': 49,
#      'defense': 49,
#      'hp': 45,
#      'name': 'Bulbasaur',
#      'special_attack': 65,
#      'special_defense': 65,
#      'speed': 45,
#      'type': 'poison'}}

# %% [markdown]
# <img src="http://imgur.com/l5NasQj.png" style="float: left; margin: 25px 15px 0px 0px; height: 25px">
#
# ## 4. Create a data structure for players
#
# ---
#
# ### 4.1
#
# In order to maintain a database of multiple players, create a dictionary that keeps track of players indexed by `player_id`.
#
# The keys of the dictionary will be `player_id` and values will be dictionaries containing each player's variables (from question 1).
#
# Construct the `players` dictionary and insert the player that you defined in question 1, then print `players`.

# %%
#Create empty dictionary
players = {}

#Function that takes a player dictinoary as an argument and appends the dictionary 'players' 
#with key as 'player_id' and the other keys as the values from the inputted dictionary.
def d2pd(dct):
    for k, v in dct.items():
        if k == 'player_id':
            players[v] = {
                'player_name': dct['player_name'],
                'time_played': dct['time_played'],
                'player_pokemon': dct['player_pokemon'],
                'gyms_visited': dct['gyms_visited']
            }

#Create player defined in question 1 in the dictionary 'players' and print
d2pd(playerDict)
pprint(players)
# Out:
# {1: {'gyms_visited': ['netflix.com', 'stackoverflow.com'],
#      'player_name': 'Rob',
#      'player_pokemon': {},
#      'time_played': 60.0}}

# %% [markdown]
# ---
#
# ### 4.2
#
# Create a new player with `player_id = 2` in the `players` dictionary. Leave the `'player_pokemon'` dictionary empty. Append `'alcatraz'` and `'pacific_beach'` to the `'gyms_visited'` list for player 2.
#
# The `'player_name'` and `'time_played'` values are up to you, but must be a string and float, respectively.
#
# Remember, the player_id is the key for the player in the players dictionary.
#
# Print the `players` dictionary with the new player inserted.

# %%
#Create player2 dictionary
player2 = {
    'player_id': 2,
    'player_name': 'Leeroy Jenkins',
    'time_played': 10.00,
    'player_pokemon': {},
    'gyms_visited': []
}

#Append 'alcatraz' and 'pacific_beach' to 'gyms_visited' key in player 2
player2['gyms_visited'].append('alcatraz')
player2['gyms_visited'].append('pacific_beach')

#Add player2 dictionary to players dictionary and print
d2pd(player2)
pprint(players)
# Out:
# {1: {'gyms_visited': ['netflix.com', 'stackoverflow.com'],
#      'player_name': 'Rob',
#      'player_pokemon': {},
#      'time_played': 60.0},
#  2: {'gyms_visited': ['alcatraz', 'pacific_beach'],
#      'player_name': 'Leeroy Jenkins',
#      'player_pokemon': {},
#      'time_played': 10.0}}

# %% [markdown]
# <img src="http://imgur.com/l5NasQj.png" style="float: left; margin: 25px 15px 0px 0px; height: 25px">
#
# ## 5. Add captured pokemon for each player
#
# ---
#
# The `'player_pokemon'` keyed dictionaries for each player keep track of which of the pokemon each player has.
#
# The keys of the `'player_pokemon'` dictionaries are the pokemon ids that correspond to the ids in the `pokedex` dictionary you created earlier. The values are integers specifying the stats for the pokemon.
#
# Give player 1 a squirtle. Give player 2 charmander and a bulbasaur.
#
# Print the players dictionary after adding the pokemon for each player.

# %%
players[1]['player_pokemon'].update({2:pDex[2]})
players[2]['player_pokemon'].update({1:pDex[1]})
players[2]['player_pokemon'].update({3:pDex[3]})

pprint(players)
# Out:
# {1: {'gyms_visited': ['netflix.com', 'stackoverflow.com'],
#      'player_name': 'Rob',
#      'player_pokemon': {2: {'attack': 48,
#                             'defense': 65,
#                             'hp': 44,
#                             'name': 'Squirtle',
#                             'special_attack': 50,
#                             'special_defense': 64,
#                             'speed': 43,
#                             'type': 'water'}},
#      'time_played': 60.0},
#  2: {'gyms_visited': ['alcatraz', 'pacific_beach'],
#      'player_name': 'Leeroy Jenkins',
#      'player_pokemon': {1: {'attack': 52,
#                             'defense': 43,
#                             'hp': 39,
#                             'name': 'Charmander',
#                             'special_attack': 60,
#                             'special_defense': 50,
#                             'speed': 65,
#                             'type': 'fire'},
# ...

# %% [markdown]
# ## 6. What gyms have players visited?
#
# ---
# <img src="http://imgur.com/l5NasQj.png" style="float: left; margin: 25px 15px 0px 0px; height: 25px">
# ### 6.1
#
# Write a for-loop that:
#
# 1. Iterates through the `pokemon_gyms` list of gym locations you defined before.
# 2. For each gym, iterate through each player in the `players` dictionary with a second, internal for-loop.
# 3. If the player has visited the gym, print out "[player] has visited [gym location].", filling in [player] and [gym location] with the current player's name and current gym location.

# %%
for gym in gyms:
    for pl in players:
        if gym in players[pl]['gyms_visited']:
            print(players[pl]['player_name'] + ' has visited ' + gym + '.')
# Out:
# Rob has visited netflix.com.
# Rob has visited stackoverflow.com.

# %% [markdown]
# <img src="http://imgur.com/xDpSobf.png" style="float: left; margin: 25px 15px 0px 0px; height: 25px">
# ### 6.2
#
# How many times did that loop run? If you have N gyms and also N players, how many times would it run as a function of N?
#
# Can you think of a more efficient way to accomplish the same thing?
#
# (You can write your answer as Markdown text.)

# %%
A: Assuming N gyms and also N players, the number of loops would be N ** 2

# %%
#With a concatenated string for the 'gyms' list, the loop should only check 1 string rather
#than a list of strings. Loop runs N times.
#*Very hacky, would not recommend!

conGyms = ','.join(gyms)

for i in players:
    for k in players[i]['gyms_visited']:
        if k in conGyms:
            print(players[i]['player_name'] + ' has visited ' + k + ' .')
# Out:
# Rob has visited netflix.com .
# Rob has visited stackoverflow.com .

# %% [markdown]
# <img src="http://imgur.com/l5NasQj.png" style="float: left; margin: 25px 15px 0px 0px; height: 25px">
#
# ## 7. Calculate player "power".
#
# ---
#
# Define a function that will calculate a player's "power". Player power is defined as the sum of the base statistics all of their pokemon.
#
# Your function will:
#
# 1. Accept the `players` dictionary, `pokedex` dictionary, and a player_id as arguments.
# 2. For the specified player_id, look up that player's pokemon and their level(s).
# 3. Find and aggregate the attack and defense values for each of the player's pokemon from the `pokedex` dictionary.
# 4. Print "[player name]'s power is [player power].", where the player power is the sum of the base statistics for all of their pokemon.
# 5. Return the player's power value.
#
# Print out the pokemon power for each of your players.

# %%
#Function that takes arguments, players dictionary, pokedex dictionary, and player_id
#and returns the aggregate of all base statistics of each pokemon and returns the value.
def power(players, pDex, pID):
    pPower = 0
    for pokemon in players[pID]['player_pokemon']:
        #Aggregates each pokemon's attack and defense and prints value as per task (3)
        att_def = players[pID]['player_pokemon'][pokemon]['attack'] + players[pID]['player_pokemon'][pokemon]['defense']
        print(players[pID]['player_pokemon'][pokemon]['name'] + "'s power is " + str(att_def))
        
        #Aggregate all base statistics of each pokemon for the player
        pPower = pPower + players[pID]['player_pokemon'][pokemon]['attack'] +\
                players[pID]['player_pokemon'][pokemon]['defense'] +\
                players[pID]['player_pokemon'][pokemon]['hp'] +\
                players[pID]['player_pokemon'][pokemon]['special_attack'] +\
                players[pID]['player_pokemon'][pokemon]['special_defense'] +\
                players[pID]['player_pokemon'][pokemon]['speed']
    print('')
    print(players[pID]['player_name'] + "'s power is " + str(pPower))
    #return player's power value as per task (5)
    return pPower
        
power(players, pDex, 1)
print('----------------------------------')
power(players, pDex, 2)
# Out:
# Squirtle's power is 113
#
# Rob's power is 314
# ----------------------------------
# Charmander's power is 95
# Bulbasaur's power is 98
#
# Leeroy Jenkins's power is 627
# 627

# %% [markdown]
# <img src="http://imgur.com/l5NasQj.png" style="float: left; margin: 25px 15px 0px 0px; height: 25px">
#
# ## 8. Load a pokedex file containing all the pokemon
#
# ---
#
# ### 8.1
#
# While you were putting together the prototype code, your colleagues were preparing a dataset of Pokemon and their attributes. (This was a rush job, so they may have picked some crazy values for some...)
#
# The code below loads information from a comma separated value (csv) file. You need to parse this string into a more useable format. The format of the string is:
#
# - Rows are separated by newline characters: \n
# - Columns are separated by commas: ,
# - All cells in the csv are double quoted. Ex: "PokedexNumber" is the first cell of the first row.
#
#
# Using for-loops, create a list of lists where each list within the overall list is a row of the csv/matrix, and each element in that list is a cell in that row. Additional criteria:
#
# 1. Quotes are removed from each cell item.
# 2. Numeric column values are converted to floats.
# 3. There are some cells that are empty and have no information. For these cells put a -1 value in place.
#
# Your end result is effectively a matrix. Each list in the outer list is a row, and the *j*th elements of list together form the *j*th column, which represents a data attribute. The first three lists in your pokedex list should look like this:
#
#     ['PokedexNumber', 'Name', 'Type', 'Total', 'HP', 'Attack', 'Defense', 'SpecialAttack', 'SpecialDefense', 'Speed']
#     [1.0, 'Bulbasaur', 'GrassPoison', 318.0, 45.0, 49.0, 49.0, 65.0, 65.0, 45.0]
#     [2.0, 'Ivysaur', 'GrassPoison', 405.0, 60.0, 62.0, 63.0, 80.0, 80.0, 60.0]

# %%
# Code to read in pokedex info
raw_pd = ''
pokedex_file = 'pokedex_basic.csv'
pokeDex = []

#Open pokedex_file and create list of lists called 'pokeDex'
#Remove quotes and '\n' instances while appending to 'pokeDex'
with open(pokedex_file, 'r') as f:
#    raw_pd = f.read()
    for i in f:
        sList = i.split(',')
        tList = []
        for k in sList:
            temp = k.strip('\n')
            temp = temp.strip('"')
            tList.append(temp)
        pokeDex.append(tList)

#Convert numeric column values in 'pokeDex' as floats
for subList in pokeDex:
    if subList[0] == 'PokedexNumber':
        pass
    else:
        subList[0] = float(int(subList[0]))
        subList[3] = float(int(subList[3]))
        subList[4] = float(int(subList[4]))
        subList[5] = float(int(subList[5]))
        subList[6] = float(int(subList[6]))        
        subList[7] = float(int(subList[7]))
        subList[8] = float(int(subList[8]))        
        subList[9] = float(int(subList[9]))

#Replace empty cells or cells with 0.0 value with -1 (if any)
indexer = 0
for row in pokeDex:
    for cell in row:
        if cell == '' or cell == 0.0:
            pokeDex[indexer][pokeDex[indexer].index(cell)] = -1
    indexer += 1
    
#Print top 3 lists as per above example
printer = 0
while printer < 3:
    print(pokeDex[printer])
    printer += 1
# Out:
# ['PokedexNumber', 'Name', 'Type', 'Total', 'HP', 'Attack', 'Defense', 'SpecialAttack', 'SpecialDefense', 'Speed']
# [1.0, 'Bulbasaur', 'GrassPoison', 318.0, 45.0, 49.0, 49.0, 65.0, 65.0, 45.0]
# [2.0, 'Ivysaur', 'GrassPoison', 405.0, 60.0, 62.0, 63.0, 80.0, 80.0, 60.0]

# %% [markdown]
# <img src="http://imgur.com/xDpSobf.png" style="float: left; margin: 25px 15px 0px 0px; height: 25px">
#
# ### 8.2 Parse the raw pokedex with list comprehensions
#
# ---
#
# Perform the same parsing as above, but **using only a single list comprehension** instead of for loops. You may have nested list comprehensions within the main list comprehension! The output should be exactly the same.

# %% [markdown]
# <img src="http://imgur.com/l5NasQj.png" style="float: left; margin: 25px 15px 0px 0px; height: 25px">
#
# ## 9. Write a function to generate the full pokedex
#
# ---
#
# Write a function that recreates the pokedex you made before, but with the data read in from the full pokemon file. The `PokedexNumber` should be used as the `pokemon_id` key values for the dictionary of pokemon.
#
# Your function should:
#
# 1. Take the parsed pokedex information you created above as an argument.
# 2. Return a dictionary in the same format as your original pokedex you created before containing the information from the parsed full pokedex file.
#
# To test the function, print out the pokemon with id = 100.

# %%
#Function takes parsed pokedex information as an argument and returns a dictionary with keys 
#as the pokemon ID and the values as a dictionary of its attributes
def fullPdex(data):
    for row in data:
        if row[0] == 'PokedexNumber':
            pass
        else:
            pDex[row[0]] = {
                'Name': row[1],
                'Type': row[2],
                'Total': row[3],
                'HP': row[4],
                'Attack': row[5],
                'Defense': row[6],
                'SpecialAttack': row[7],
                'SpecialDefense': row[8],
                'Speed': row[9]
            }
    return pDex
            
fullPdex(pokeDex)



pprint({100:pDex[100]})
# Out:
# {100: {'Attack': 30.0,
#        'Defense': 50.0,
#        'HP': 40.0,
#        'Name': 'Voltorb',
#        'SpecialAttack': 55.0,
#        'SpecialDefense': 55.0,
#        'Speed': 100.0,
#        'Total': 330.0,
#        'Type': 'Electric'}}

# %% [markdown]
# <img src="http://i.imgur.com/GCAf1UX.png" style="float: left; margin: 25px 15px 0px 0px; height: 25px">
#
# ## 10. Write a function to generate a "filtered" pokedex
# ---
# Your function should:
# 1. Take the parsed pokedex information you created above as an argument.
# 1. Take a dictionary as a parameter with keys matching the features of the Pokedex, filtering by exact match for string type values, and/or filter continuous variables specified value that is greater than or equal to the dictionary key parameter.
# 1. Return multiple elements from the Pokedex
#
# Example:
#
# ```python
#
# # Only filter based on parameters passed
# filter_options = {
#     'Attack':   25,
#     'Defense':  30,
#     'Type':     'Electric'
# }
#
# # Return records with attack >= 24, defense >= 30, and type == "Electric"
# # Also anticipate that other paramters can also be passed such as "SpecialAttack", "Speed", etc.
# filtered_pokedex(pokedex_data, filter=filter_options)
#
# # Example output:
# # [{'Attack': 30.0,
# #  'Defense': 50.0,
# #  'HP': 40.0,
# #  'Name': 'Voltorb',
# #  'SpecialAttack': 55.0,
# #  'SpecialDefense': 55.0,
# #  'Speed': 100.0,
# #  'Total': 330.0,
# #  'Type': 'Electric'},
# #  {'Attack': 30.0,
# #  'Defense': 33.0,
# #  'HP': 32.0,
# #  'Name': 'Pikachu',
# #  'SpecialAttack': 55.0,
# #  'SpecialDefense': 55.0,
# #  'Speed': 100.0,
# #  'Total': 330.0,
# #  'Type': 'Electric'},
# #  ... etc
# #  ]
#
# ```

# %%
filter_options = {
    'Attack': 100,
    'Defense': 80,
    #'Type': 'Electric'
    #'Name': 'Pikachu'
}

# %%
#Function takes parsed pokemon data and 'filtered_options' defined above as arguments
def filteredpDex(data, filter_options):

    returnList = []
    filteredDict = {}
    
#For 'Type' and 'Name' filters, iterate through the pokemon list (argument) and see if the
#filter string matches the pokemon's value string. If match, create dictionary key in 
#filteredDict dictionary and set value as 1- if it already exists add +1.
    for k, v in filter_options.items():
        if k == 'Type' or k == 'Name':
            for row in data:
                if filter_options[k] == row[pokeDex[0].index(k)]:
                    if row[1] in filteredDict:
                        filteredDict[row[1]] += 1
                    else:
                        filteredDict[row[1]] = 1
#For all filters outside 'Type' and 'Name', iterate through the pokemon list (argument) and 
#see if pokemon's value for attribute is greater or equal to value in 'filter_options'. If yes,
#create dictionary key in 'filteredDict' dictionary and set value as 1- if it already exists 
#add +1.
        else:
            for row in data:
                #To ignore header
                if row[0] != 'PokedexNumber':
                    if row[pokeDex[0].index(k)] >= v:
                        if row[1] in filteredDict:
                            filteredDict[row[1]] += 1
                        else:
                            filteredDict[row[1]] = 1

#Append to 'returnList' the dictionaries of all pokemon in pDex that match all parameters in
#'filter_options".
    for pokemon, count in filteredDict.items():
        if count == len(filter_options):
            for i in pokeDex:
                if i[1] == pokemon:
                    returnList.append(pDex[i[0]])
    
    return returnList

    
            

        
filteredpDex(pokeDex, filter_options)
# Out:
# [{'Attack': 100.0,
#   'Defense': 123.0,
#   'HP': 80.0,
#   'Name': 'VenusaurMega Venusaur',
#   'SpecialAttack': 122.0,
#   'SpecialDefense': 120.0,
#   'Speed': 80.0,
#   'Total': 625.0,
#   'Type': 'GrassPoison'},
#  {'Attack': 104.0,
#   'Defense': 78.0,
#   'HP': 78.0,
#   'Name': 'CharizardMega Charizard Y',
#   'SpecialAttack': 159.0,
#   'SpecialDefense': 115.0,
#   'Speed': 100.0,
#   'Total': 634.0,
#   'Type': 'FireFlying'},
#  {'Attack': 103.0,
#   'Defense': 120.0,
#   'HP': 79.0,
#   'Name': 'BlastoiseMega Blastoise',
#   'SpecialAttack': 135.0,
#   'SpecialDefense': 115.0,
#   'Speed': 78.0,
#   'Total': 630.0,
#   'Type': 'Water'},
#  {'Attack': 100.0,
#   'Defense': 110.0,
#   'HP': 75.0,
#   'Name': 'Sandslash',
#   'SpecialAttack': 45.0,
#   'SpecialDefense': 55.0,
#   'Speed': 65.0,
#   'Total': 450.0,
#   'Type': 'Ground'},
#  {'Attack': 110.0,
#   'Defense': 80.0,
#   'HP': 90.0,
#   'Name': 'Arcanine',
#   'SpecialAttack': 100.0,
#   'SpecialDefense': 80.0,
# ...

# %% [markdown]
# ## 9. Descriptive statistics on the prototype pokedex
#
# <img src="http://imgur.com/l5NasQj.png" style="float: left; margin: 25px 15px 0px 0px; height: 25px">
# ### 9.1
#
# What is the population mean and standard deviation of the "Total" attribute for all characters in the Pokedex?

# %%
import numpy as np

tList = []

for row in pokeDex:
    if row[3] != 'Total':
        tList.append(row[3])
        
pMean = np.mean(tList).round(2)
pStd = np.std(tList).round(2)

# %%
print('"Total" attribute mean is, {}'.format(pMean))
# Out:
# "Total" attribute mean is, 435.13

# %%
print('"Total" attribute standard deviation is, {}'.format(pStd))
# Out:
# "Total" attribute standard deviation is, 119.96

# %% [markdown]
# <img src="http://imgur.com/l5NasQj.png" style="float: left; margin: 25px 15px 0px 0px; height: 25px">
# ### 9.2
#
# The game is no fun if the characters are wildly unbalanced! Are any characters "overpowered", which we'll define as having a "Total" more than three standard deviations from the population mean?

# %%
pDct = {}
overPowered = []
underPowered = []

for row in pokeDex:
    if row[3] != 'Total':
        pDct[row[1]] = row[3]

#'pMean' and 'pStd' defined in problem 9.1
lcl = pMean - (3 * pStd) 
ucl = pMean + (3 * pStd)
for pokemon, stat in pDct.items():
    if stat > ucl:
        overPowered.append(pokemon)
    elif stat < lcl:
        underPowered.append(pokemon)

print('Over powered pokemon: ')
print(overPowered)
print('')
print("Under powered pokemon: ")
print(underPowered)
# Out:
# Over powered pokemon:
# ['MewtwoMega Mewtwo X']
#
# Under powered pokemon:
# []

# %%
pDct
# Out:
# {'Abomasnow': 494.0,
#  'AbomasnowMega Abomasnow': 594.0,
#  'Abra': 310.0,
#  'Absol': 465.0,
#  'AbsolMega Absol': 565.0,
#  'Accelgor': 495.0,
#  'AegislashBlade Forme': 520.0,
#  'AegislashShield Forme': 520.0,
#  'Aerodactyl': 515.0,
#  'AerodactylMega Aerodactyl': 615.0,
#  'Aggron': 530.0,
#  'AggronMega Aggron': 630.0,
#  'Aipom': 360.0,
#  'Alakazam': 500.0,
#  'AlakazamMega Alakazam': 590.0,
#  'Alomomola': 470.0,
#  'Altaria': 490.0,
#  'AltariaMega Altaria': 590.0,
#  'Amaura': 362.0,
#  'Ambipom': 482.0,
#  'Amoonguss': 464.0,
#  'Ampharos': 510.0,
#  'AmpharosMega Ampharos': 610.0,
#  'Anorith': 355.0,
#  'Arbok': 438.0,
#  'Arcanine': 555.0,
#  'Arceus': 720.0,
#  'Archen': 401.0,
#  'Archeops': 567.0,
#  'Ariados': 390.0,
#  'Armaldo': 495.0,
#  'Aromatisse': 462.0,
#  'Aron': 330.0,
#  'Articuno': 580.0,
#  'Audino': 445.0,
#  'AudinoMega Audino': 545.0,
#  'Aurorus': 521.0,
#  'Avalugg': 514.0,
#  'Axew': 320.0,
#  'Azelf': 580.0,
#  'Azumarill': 420.0,
# ...

# %% [markdown]
# <img src="http://imgur.com/xDpSobf.png" style="float: left; margin: 25px 15px 0px 0px; height: 25px">
#
# ## 10. Calibrate the frequency of Pokemon
#
# The design team wants you to make the powerful Pokemon rare, and the weaklings more common. How would you set the probability $p_i$ of finding Pokemon *i* each time a player visits a gym?
#
# Write a function that takes in a Pokedex number and returns a value $p_i$ for that character.
#
# Hint: there are many ways you could do this. What do _you_ think makes sense? Start with simplifying assumptions: for example, you could assume that the probabilities of encountering any two Pokemon on one visit to a gym are independent of each other.

# %%
#Probability of a pokemon's encounter is based on the 'total' attribute's distance from the 
#standard deviation. (ie: 3std below mean will have the highest encounter probability)

pokeBasket = []

for k, v in pDct.items():  
    if v < (pMean - (3 * pStd)):
        [pokeBasket.append(k) for _ in range(7)]
    elif v < (pMean - (2 * pStd)):
        [pokeBasket.append(k) for _ in range(6)]
    elif v < (pMean - (pStd)):
        [pokeBasket.append(k) for _ in range(5)]
    elif v < pMean:
        [pokeBasket.append(k) for _ in range(4)]
    elif v < (pMean + (pStd)):
        [pokeBasket.append(k) for _ in range(3)]
    elif v < (pMean + (2 * pStd)):
        [pokeBasket.append(k) for _ in range(2)]
    elif v < (pMean + (3 * pStd)) or v >= (pMean + (3 * pStd)):
        pokeBasket.append(k)      
        
basketTotal = len(pokeBasket)

#Function takes pokemon's pokedex number and returns the probability of its encounter rate
def pokemonEncounter(pokemon):
    name = pDex[pokemon]['Name']
    prob = pokeBasket.count(name) / basketTotal
    return prob

# %%
#Example
pokemonEncounter(5)
# Out:
# 0.0014234875444839859
